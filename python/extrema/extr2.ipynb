# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import interpolate
from scipy.signal import argrelextrema
import time

from math import *

# %%
dw_samples=np.linspace(0.05, 0.125, 50)
plt.figure(figsize=(7,7))
dual_border=np.fromfile(file='/Users/mryodo/Documents/num_res/1409/PT1409_50_10000_extr2_cor025.out', sep='\n')
plt.plot(dw_samples, dual_border/1000, label='Second extremum appearance')
dual_border2=np.fromfile(file='/Users/mryodo/Documents/num_res/1409/PT1409_50_10000_extr_break_fast_long_025.out', sep='\n')
plt.plot(dw_samples, dual_border2/1000, 'r', label='Catastrophy appearance')
plt.xlabel(r'dw', fontsize=20)
plt.ylabel(r'Time of second extr appearance, t', fontsize=20)
plt.legend()
plt.show()

#d=0.25, #dd=-0.2

# %%
dw_samples=np.linspace(0.05, 0.125, 50)
plt.figure(figsize=(7,7))
dual_border=np.fromfile(file='/Users/mryodo/Documents/num_res/1409/PT1409_50_10000_extr2_cor025.out', sep='\n')
plt.plot(np.log(dw_samples), np.log(dual_border/1000), label='Second extremum appearance')
dual_border2=np.fromfile(file='/Users/mryodo/Documents/num_res/1409/PT1409_50_10000_extr_break_fast_long_025.out', sep='\n')
plt.plot(np.log(dw_samples), np.log(dual_border2/1000), 'r', label='Catastrophy appearance')
plt.xlabel(r'dw', fontsize=20)
plt.ylabel(r'Time of second extr appearance, t', fontsize=20)
plt.legend()
plt.show()

#d=0.25, #dd=-0.2

# %%
dw_samples=np.linspace(0.05, 0.125, 50)
plt.figure(figsize=(7,7))
dual_border=np.fromfile(file='/Users/mryodo/Documents/num_res/1409/PT1409_50_10000_extr2_cor.out', sep='\n')
plt.plot(dw_samples, dual_border[50:]/1000, label='Second extremum appearance')
dual_border2=np.fromfile(file='/Users/mryodo/Documents/num_res/1409/PT1409_50_10000_extr_break_fast_long.out', sep='\n')
plt.plot(dw_samples, dual_border2/1000, 'r',  label='Catastrophy appearance')
plt.xlabel(r'dw', fontsize=20)
plt.ylabel(r'Time of second extr appearance, t', fontsize=20)
plt.legend()
plt.show()

#d=2.5, #dd=-2.45

# %%
dw_samples=np.linspace(0.05, 0.125, 50)
plt.figure(figsize=(7,7))
dual_border=np.fromfile(file='/Users/mryodo/Documents/num_res/1409/PT1409_50_10000_extr2_cor.out', sep='\n')
plt.plot(np.log(dw_samples), np.log(dual_border[50:]/1000), label='Second extremum appearance')
dual_border2=np.fromfile(file='/Users/mryodo/Documents/num_res/1409/PT1409_50_10000_extr_break_fast_long.out', sep='\n')
plt.plot(np.log(dw_samples), np.log(dual_border2/1000), 'r',  label='Catastrophy appearance')
plt.xlabel(r'dw', fontsize=20)
plt.ylabel(r'Time of second extr appearance, t', fontsize=20)
plt.legend()
plt.show()

#d=2.5, #dd=-2.45
