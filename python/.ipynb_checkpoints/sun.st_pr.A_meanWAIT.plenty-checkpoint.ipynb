# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import interpolate

import time

from math import *

# %%
res=np.loadtxt('PT1210_20_8000_q_A_cor.out', delimiter=',')
res2=np.loadtxt('PT1210_20_8000_q2_A_cor.out', delimiter=',')
res3=np.loadtxt('PT1210_20_8000_q3_A_cor.out', delimiter=',')

# %%
A_cuts=20
sample=100
alpha_s=np.linspace(0.995, 0.99995, A_cuts)

# %%
from scipy.signal import savgol_filter

plt.figure(figsize=(10,10))
plt.plot(alpha_s, np.mean(res3, axis=1))
plt.plot(alpha_s, savgol_filter(np.mean(res3, axis=1), 9, 4), 'k--')
plt.show()

# %%
plt.figure(figsize=(10,10))
#plt.plot(alpha_s, np.mean(res3, axis=1))
plt.plot(np.log(1-alpha_s), np.log(savgol_filter(np.mean(res3, axis=1), 9, 6)), 'k--')
plt.show()
# Out:
# /usr/lib/python3.6/site-packages/ipykernel/__main__.py:3: RuntimeWarning: invalid value encountered in log
#   app.launch_new_instance()

# %%
res_q=res
res_q2=res2

res_q[res3==1]=np.nan
res_q2[res3==1]=np.nan

res_clean=np.loadtxt('PT1210_20_8000_q_A_cor.out', delimiter=',')

f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,7))
for i in range(sample):
    ax1.plot(alpha_s, res_clean[:, i])
for i in range(sample):
    ax2.plot(alpha_s, res_q[:, i])
#plt.plot(alpha_s, res2[:, -1])    
plt.show()
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,7))
for i in range(sample):
    ax1.plot(alpha_s, res_clean[:, i], alpha=0.2)
ax1.plot(alpha_s, np.mean(res_clean, axis=1))
for i in range(sample):
    ax2.plot(alpha_s, res_q[:, i], alpha=0.2)
ax2.plot(alpha_s, np.nanmean(res_q, axis=1))
#plt.plot(alpha_s, res2[:, -1])    
plt.show()

# %%
res_clean2=np.loadtxt('PT1210_20_8000_q2_A_cor.out', delimiter=',')
res_clean2.shape

f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,7))
for i in range(sample):
    ax1.plot(alpha_s, res_clean2[:, i])
for i in range(sample):
    ax2.plot(alpha_s, res_q2[:, i])
#plt.plot(alpha_s, res2[:, -1])    
plt.show()
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,7))
for i in range(sample):
    ax1.plot(alpha_s, res_clean2[:, i], alpha=0.2)
ax1.plot(alpha_s, np.mean(res_clean2, axis=1))
for i in range(sample):
    ax2.plot(alpha_s, res_q2[:, i], alpha=0.2)
ax2.plot(alpha_s, np.nanmean(res_q2, axis=1))
#plt.plot(alpha_s, res2[:, -1])    
plt.show()

# %%
res=np.loadtxt('PT12(2)10_20_8000_q_A_cor.out', delimiter=',')
res2=np.loadtxt('PT12(2)10_20_8000_q2_A_cor.out', delimiter=',')
res3=np.loadtxt('PT12(2)10_20_8000_q3_A_cor.out', delimiter=',')

# %%
from scipy.signal import savgol_filter

plt.figure(figsize=(10,10))
plt.plot(alpha_s, np.mean(res3, axis=1))
plt.plot(alpha_s, savgol_filter(np.mean(res3, axis=1), 9, 4), 'k--')
plt.show()

# %%
plt.figure(figsize=(10,10))
#plt.plot(alpha_s, np.mean(res3, axis=1))
plt.plot(np.log(1-alpha_s), np.log(savgol_filter(np.mean(res3, axis=1), 9, 6)), 'k--')
plt.show()
# Out:
# /usr/lib/python3.6/site-packages/ipykernel/__main__.py:3: RuntimeWarning: invalid value encountered in log
#   app.launch_new_instance()

# %%
res_q=res
res_q2=res2

res_q[res3==1]=np.nan
res_q2[res3==1]=np.nan

res_clean=np.loadtxt('PT12(2)10_20_8000_q_A_cor.out', delimiter=',')

f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,7))
for i in range(sample):
    ax1.plot(alpha_s, res_clean[:, i])
for i in range(sample):
    ax2.plot(alpha_s, res_q[:, i])
#plt.plot(alpha_s, res2[:, -1])    
plt.show()
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,7))
for i in range(sample):
    ax1.plot(alpha_s, res_clean[:, i], alpha=0.2)
ax1.plot(alpha_s, np.mean(res_clean, axis=1))
for i in range(sample):
    ax2.plot(alpha_s, res_q[:, i], alpha=0.2)
ax2.plot(alpha_s, np.nanmean(res_q, axis=1))
#plt.plot(alpha_s, res2[:, -1])    
plt.show()

# %%
res_clean2=np.loadtxt('PT12(2)10_20_8000_q2_A_cor.out', delimiter=',')
res_clean2.shape

f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,7))
for i in range(sample):
    ax1.plot(alpha_s, res_clean2[:, i])
for i in range(sample):
    ax2.plot(alpha_s, res_q2[:, i])
#plt.plot(alpha_s, res2[:, -1])    
plt.show()
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,7))
for i in range(sample):
    ax1.plot(alpha_s, res_clean2[:, i], alpha=0.2)
ax1.plot(alpha_s, np.mean(res_clean2, axis=1))
for i in range(sample):
    ax2.plot(alpha_s, res_q2[:, i], alpha=0.2)
ax2.plot(alpha_s, np.nanmean(res_q2, axis=1))
#plt.plot(alpha_s, res2[:, -1])    
plt.show()

# %%
res=np.loadtxt('PT12(3)10_20_8000_q_A_cor.out', delimiter=',')
res2=np.loadtxt('PT12(3)10_20_8000_q2_A_cor.out', delimiter=',')
res3=np.loadtxt('PT12(3)10_20_8000_q3_A_cor.out', delimiter=',')


from scipy.signal import savgol_filter

plt.figure(figsize=(10,10))
plt.plot(alpha_s, np.mean(res3, axis=1))
plt.plot(alpha_s, savgol_filter(np.mean(res3, axis=1), 9, 4), 'k--')
plt.show()

plt.figure(figsize=(10,10))
#plt.plot(alpha_s, np.mean(res3, axis=1))
plt.plot(np.log(1-alpha_s), np.log(savgol_filter(np.mean(res3, axis=1), 9, 6)), 'k--')
plt.show()

res_q=res
res_q2=res2

res_q[res3==1]=np.nan
res_q2[res3==1]=np.nan

res_clean=np.loadtxt('PT12(3)10_20_8000_q_A_cor.out', delimiter=',')

f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,7))
for i in range(sample):
    ax1.plot(alpha_s, res_clean[:, i])
for i in range(sample):
    ax2.plot(alpha_s, res_q[:, i])
#plt.plot(alpha_s, res2[:, -1])    
plt.show()
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,7))
for i in range(sample):
    ax1.plot(alpha_s, res_clean[:, i], alpha=0.2)
ax1.plot(alpha_s, np.mean(res_clean, axis=1))
for i in range(sample):
    ax2.plot(alpha_s, res_q[:, i], alpha=0.2)
ax2.plot(alpha_s, np.nanmean(res_q, axis=1))
#plt.plot(alpha_s, res2[:, -1])    
plt.show()

res_clean2=np.loadtxt('PT12(3)10_20_8000_q2_A_cor.out', delimiter=',')
res_clean2.shape

f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,7))
for i in range(sample):
    ax1.plot(alpha_s, res_clean2[:, i])
for i in range(sample):
    ax2.plot(alpha_s, res_q2[:, i])
#plt.plot(alpha_s, res2[:, -1])    
plt.show()
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,7))
for i in range(sample):
    ax1.plot(alpha_s, res_clean2[:, i], alpha=0.2)
ax1.plot(alpha_s, np.mean(res_clean2, axis=1))
for i in range(sample):
    ax2.plot(alpha_s, res_q2[:, i], alpha=0.2)
ax2.plot(alpha_s, np.nanmean(res_q2, axis=1))
#plt.plot(alpha_s, res2[:, -1])    
plt.show()
# Out:
# /usr/lib/python3.6/site-packages/ipykernel/__main__.py:39: RuntimeWarning: Mean of empty slice
