# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import interpolate
from scipy.signal import argrelextrema
import time

from math import *

# %%
dw_samples=np.linspace(0.05, 1.25, 200)
dual_border=np.fromfile(file='PT2407_50_20000_extr_break.out', sep='\n')
dual_border[199]=2

plt.figure(figsize=(7,7))
plt.plot(dw_samples, dual_border)
plt.show()

# %%
dual_border[199]=2

# %%
from scipy.signal import argrelextrema
dmin=argrelextrema(dual_border, np.less)

# %%
plt.figure(figsize=(7,7))
plt.plot(dw_samples, dmin)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-3a11f7c1a6cf> in <module>()
#       1 plt.figure(figsize=(7,7))
# ----> 2 plt.plot(dw_samples, dmin)
#       3 plt.show()
#
# /usr/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3315                       mplDeprecation)
#    3316     try:
# -> 3317         ret = ax.plot(*args, **kwargs)
#    3318     finally:
#    3319         ax._hold = washold
#
# /usr/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# ...
